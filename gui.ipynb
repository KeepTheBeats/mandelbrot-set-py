# %%
import naive

naive.main()

# %%
import use_vectorize

use_vectorize.main()

# %%
import use_guvectorize

use_guvectorize.main()

# %%
import use_multiprocessing

use_multiprocessing.main()
# Out:
# maxWorkers: 8
# Using multiple processors.
# Start to submit tasks
# submit task i in [0, 63)
# submit task i in [63, 126)
# submit task i in [126, 189)
# submit task i in [189, 252)
# submit task i in [252, 314)
# submit task i in [314, 376)
# submit task i in [376, 438)
# submit task i in [438, 500)
# Start to wait for tasks
# All tasks are done!
