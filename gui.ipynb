# %%
import naive

naive.main()

# %%
import use_vectorize

use_vectorize.main()

# %%
import use_guvectorize

use_guvectorize.main()

# %%
import use_multiprocessing

use_multiprocessing.main()
# Out:
# maxWorkers: 8
# Using multiple processors.
# Start to submit tasks
# submit task i in [0, 626)
# submit task i in [626, 1251)
# submit task i in [1251, 1876)
# submit task i in [1876, 2501)
# submit task i in [2501, 3126)
# submit task i in [3126, 3751)
# submit task i in [3751, 4376)
# submit task i in [4376, 5001)
# Start to wait for tasks
# All tasks are done!
